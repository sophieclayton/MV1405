# %%
% matplotlib inline

from __future__ import division
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
import time as tm
import gsw as sw
from scipy.optimize import curve_fit
import FlowCytometryTools as fcm

import numpy.ma as ma

from mpl_toolkits.basemap import Basemap, cm
from netCDF4 import Dataset as NetCDFFile

from matplotlib import rcParams, rc
rcParams.update({'figure.autolayout': True})
rcParams.update({'font.family': 'serif'})
rcParams.update({'font.serif': 'Times New Roman'})
#rc('text', usetex=True)
# Out:
# /Users/archie/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
# plot a cytogram

fig1 = plt.figure(1,figsize=(10,10), dpi = 600)

indir = '../data/FCM/MV1405_FCM/'
datafile = '%s105.fcs'% indir

print datafile

# Load data
tsample = fcm.FCMeasurement(ID='Test Sample', datafile=datafile)

# Plot
tsample.plot(['FSC small stuff', '692-40 small stuff'], cmap = 'RdYlBu_r', vmin = 2.5, vmax = 20)
plt.xlabel('FSC', fontsize = 28)
plt.ylabel('Fluorescence (692 nm)', fontsize = 28)
plt.xticks(fontsize = 24)
plt.yticks(fontsize = 24)

#fcm.grid(True)

plt.show() # <-- Uncomment when running as a script.

fig1.savefig('../figures/example_cytogram_105.png', bbox_inches='tight')
# Out:
# ../data/FCM/MV1405_FCM/105.fcs
